# %% [markdown]
# #Bienvenida

# %% [markdown]
# ##Aprendiendo a usar print
# print() es un método que permite imprimir
# información en consola:
#
# Sintaxis
# ```
# if (condicion)== verdadera
#   print("pasan cositas")
# else:
#   print("pasan otras cositas")
# ```
# El print() puede imprimir lo siguiente:
# 1. cualquier tipo de dato
# 2. cualquier método o funición (su dirección en memoria)
# 3. concatencaión de texto
# 4. operaciones matemáticas

# %% [markdown]
# ##Conociendo el input
# input() es un método con triple función
# *Declara: Toda la información que ingresa con este método, se declara automaticamente como string (caracter).
# *Lee: porque almacena en una variable.
# *Imprime: Porque lo que está entre los parentesis, se visualiza en consola.

# %%
a=24
b=50
a+b
# Out:
# 74

# %% [markdown]
# ###Concatenación
# Concatenar es unir dos tipos de diferentes datos

# %%
x=int(input("Ingrese su edad: "))
y=input("Ingrese su nombre: ")
#Ejemplo 1
print(y," tiene una edad de ",x)
# Out:
# Ingrese su edad: 18
# Ingrese su nombre: natalia
# natalia  tiene una edad de  18

# %%
#Ejemplo 1
print(y," tiene una edad de ",x)
# Out:
# natalia  tiene una edad de  18

# %%
#Ejemplo 2
print(y+" tiene una edad de "+str(x))
# Out:
# natalia tiene una edad de 18

# %%
#Ejemplo 3
print(f"{y} tiene una edad de {x}")
# Out:
# natalia tiene una edad de 18
