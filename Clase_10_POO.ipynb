# %% [markdown]
# <a href="https://colab.research.google.com/github/Nataliabarrera07/PROGCOM-A-2026/blob/main/Clase_10_POO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##PROGRAMACIÓN ORIENTADA A OBJETOS
# 1. Es un paradigma de programación
# 2. Tiene 4 pilares fundamentales:
# Herencia, polimorfismo, abstraccióm,
# encapsulamiento.
# 3. Ventajas
# * Modularidad: Manejar el código por trozos
# * Reusabilidad: Reusar clases y objetos
# * Mantenibilidad: Agregar fácilmente nuevos métodos
# * Escalabilidad: Escalar a nuevas aplicaciones desde un mismo código
# * Seguridad: No todos pueden alterar el código

# %%
colegio = input("¿Cómo se llama el colegio?: ")
estudiantes = int(input("¿Cuántos estudiantes hay en el colegio?: "))
salones = int(input("¿Cuántos salones hay en el colegio?: "))
profesores = int(input("¿Cuántos profesores hay en el colegio?: "))
grado = int(input("¿Cuántos grados hay en el colegio?: "))
materias = int(input("¿Cuántas materias hay en el colegio?: "))
baño = int(input("¿Cuántos baños hay en el colegio?: "))
materia = str(input("¿Cuáles son las materias que se imparten?: "))
descripción = str(input("¿Cuál es la descripción del colegio? Describa su techo, fachada, colores, decoración en general y escriba si tiene patio: "))

print(f"El colegio se llama {colegio} y su descripción es: {descripción},\n tiene {estudiantes} estudiantes, además cuenta con {salones} salones y {profesores} profesores, \n el colegio enseña hasta grado {grado}, y se enseñan {materias} materias, las cuales son: {materia} \n y finalmente cuenta con {baño} baños")

# %%
x = input("Qué edificio es?: ")
if x == colegio:
 colegio = input("¿Cómo se llama el colegio?: ")
 estudiantes = int(input("¿Cuántos estudiantes hay en el colegio?: "))
 salones = int(input("¿Cuántos salones hay en el colegio?: "))
 profesores = int(input("¿Cuántos profesores hay en el colegio?: "))
 grado = int(input("¿Cuántos grados hay en el colegio?: "))
 materias = int(input("¿Cuántas materias hay en el colegio?: "))
 baño = int(input("¿Cuántos baños hay en el colegio?: "))
 materia = str(input("¿Cuáles son las materias que se imparten?: "))
 descripción = str(input("¿Cuál es la descripción del colegio? Describa su techo, fachada, colores, decoración en general y escriba si tiene patio: "))

 print(f"El colegio se llama {colegio} y su descripción es: {descripción},\n tiene {estudiantes} estudiantes, además cuenta con {salones} salones y {profesores} profesores, \n el colegio enseña hasta grado {grado}, y se enseñan {materias} materias, las cuales son: {materia} \n y finalmente cuenta con {baño} baños")


else:
  descriptiva = input("describa su edificación: ")
  print(f"El edificio es: {x} y su descripción es: {descriptiva}")
